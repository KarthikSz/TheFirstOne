# %%
import nltk

# %%
import numpy as np
import random
import string

# %%
f=open('GOT.txt','r',errors = 'ignore')

# %%
raw=f.read()

# %%
raw=raw.lower()

# %%
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
sent_tokens=nltk.sent_tokenize(raw)
word_tokens=nltk.word_tokenize(raw)

# %%
sent_tokens[:2]
# Out:
# ['\n this is a good article.', 'follow the link for more information.']

# %%
lemmer=nltk.stem.WordNetLemmatizer()

# %%
def LemTokens(tokens):
    return [lemmer.lemmatize(token) for token in tokens]

# %%
remove_punct_dict=dict((ord(punct),None) for punct in string.punctuation)

# %%
print(sent_tokens)
# Out:
# ['\n this is a good article.', 'follow the link for more information.', 'page semi-protected\ngame of thrones\nfrom wikipedia, the free encyclopedia\njump to navigationjump to search\nthis article is about the television series.', 'for the novel in the series a song of ice and fire, see a game of thrones.', 'for other uses, see game of thrones (disambiguation).', '"game of thrones (franchise)" redirects here.', 'for the series of books, see a song of ice and fire.', 'game of thrones\ngame of thrones title card.jpg\ngenre\t\nfantasy\nserial drama\ncreated by\t\ndavid benioff\nd. b. weiss\nbased on\ta song of ice and fire\nby george r. r. martin\nstarring\tsee list of game of thrones characters\ntheme music composer\tramin djawadi\nopening theme\t"main title"\ncomposer(s)\tramin djawadi\ncountry of origin\tunited states\noriginal language(s)\tenglish\nno.', 'of seasons\t8\nno.', 'of episodes\t72 (list of episodes)\nproduction\nexecutive producer(s)\t\ndavid benioff\nd. b. weiss\ncaroly
# ...

# %%
nltk.download('corpus')
# Out:
# [nltk_data] Error loading corpus: Package 'corpus' not found in index
# False

# %%
from nltk.corpus import stopwords

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
sr= stopwords.words('english')

# %%
clean_tokens=word_tokens[:]

# %%
for token in word_tokens:
    if token in stopwords.words('english'):
        
        clean_tokens.remove(token)
freq = nltk.FreqDist(clean_tokens)
for key,val in freq.items():
    print(str(key) + ':' + str(val))
freq.plot(20, cumulative=False)
# Out:
# good:4
# article:9
# .:366
# follow:1
# link:1
# information:1
# page:2
# semi-protected:1
# game:62
# thrones:63
# wikipedia:1
# ,:589
# free:1
# encyclopedia:1
# jump:1
# navigationjump:1
# search:1
# television:26
# series:111
# novel:9
# song:16
# ice:16
# fire:19
# see:7
# uses:2
# (:133
# disambiguation:1
# ):133
# ``:88
# franchise:1
# '':68
# redirects:1
# books:5
# title:10
# card.jpg:1
# genre:6
# fantasy:20
# serial:2
# drama:12
# created:5
# david:17
# benioff:30
# d.:9
# b.:9
# weiss:23
# based:9
# george:11
# r.:18
# martin:31
# starring:1
# list:6
# characters:33
# theme:5
# music:6
# composer:2
# ramin:5
# djawadi:7
# opening:4
# main:20
# country:3
# origin:1
# united:9
# states:8
# original:10
# language:6
# english:7
# seasons:26
# 8:10
# episodes:28
# 72:2
# production:13
# executive:2
# producer:5
# carolyn:1
# strauss:1
# frank:1
# doelger:1
# bernadette:1
# caulfield:1
# location:8
# northern:15
# ireland:16
# croatia:4
# iceland:8
# spain:5
# malta:4
# ...

# %% [markdown]
# Bag of words:
#     Used to form a vector
#     vector similarity done using cosine similarity
# TF-idf:
#     TF-frequency of the word in given document
#     IDF:For entire corpus
#     tf*log(N/n)
#
#  Stemming: Cutting to root
#  Lemmatization:Cutting to root and synonimizing

# %%
messages=[line.rstrip() for line in open('SMSSpamCollection')]

# %%
messages[0]
# Out:
# 'ham\tGo until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...'

# %%
len(messages)
# Out:
# 5574

# %%
messages[50]
# Out:
# 'ham\tWhat you thinked about me. First time you saw me in class.'

# %%
for mess_no,message in enumerate(messages[0:10]):
    print(mess_no)
    print(message)
# Out:
# 0
# ham	Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...
# 1
# ham	Ok lar... Joking wif u oni...
# 2
# spam	Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive entry question(std txt rate)T&C's apply 08452810075over18's
# 3
# ham	U dun say so early hor... U c already then say...
# 4
# ham	Nah I don't think he goes to usf, he lives around here though
# 5
# spam	FreeMsg Hey there darling it's been 3 week's now and no word back! I'd like some fun you up for it still? Tb ok! XxX std chgs to send, Â£1.50 to rcv
# 6
# ham	Even my brother is not like to speak with me. They treat me like aids patent.
# 7
# ham	As per your request 'Melle Melle (Oru Minnaminunginte Nurungu Vettam)' has been set as your callertune for all Callers. Press *9 to copy your friends Callertune
# 8
# ...

# %%
import pandas as pd

# %%
df=pd.read_csv('SMSSpamCollection',sep='\t',names=['Label','Message'])

# %%
df.describe()
# Out:
#        Label                 Message
# count   5572                    5572
# unique     2                    5169
# top      ham  Sorry, I'll call later
# freq    4825                      30

# %%
df.groupby('Label').describe()
# Out:
#       Message
#         count unique                                                top freq
# Label
# ham      4825   4516                             Sorry, I'll call later   30
# spam      747    653  Please call our customer service representativ...    4

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
df['length']=df['Message'].apply(len)

# %%
df['length'].plot.hist(bins=150)

# %%
df.hist(column='length',by='Label',bins=60,figsize=(12,4))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0E46A3B0>,
# ...
#       dtype=object)

# %%
import string

# %%
mess="India will win the cricket world cup!"

# %%
nopunc=[c for c in mess if c not in string.punctuation]

# %%
nopunc
# Out:
# ['I',
#  'n',
#  'd',
#  'i',
#  'a',
#  ' ',
#  'w',
#  'i',
#  'l',
#  'l',
#  ' ',
#  'w',
#  'i',
#  'n',
#  ' ',
#  't',
#  'h',
#  'e',
#  ' ',
#  'c',
#  'r',
#  'i',
#  'c',
#  'k',
#  'e',
#  't',
#  ' ',
#  'w',
#  'o',
#  'r',
#  'l',
#  'd',
#  ' ',
#  'c',
#  'u',
#  'p']

# %%
from nltk.corpus import stopwords

# %%
stopwords.words('english')
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
# ...

# %%
nopunc
# Out:
# ['I',
#  'n',
#  'd',
#  'i',
#  'a',
#  ' ',
#  'w',
#  'i',
#  'l',
#  'l',
#  ' ',
#  'w',
#  'i',
#  'n',
#  ' ',
#  't',
#  'h',
#  'e',
#  ' ',
#  'c',
#  'r',
#  'i',
#  'c',
#  'k',
#  'e',
#  't',
#  ' ',
#  'w',
#  'o',
#  'r',
#  'l',
#  'd',
#  ' ',
#  'c',
#  'u',
#  'p']

# %%
place_hold=" "

# %%
for i in nopunc:
    place_hold=place_hold+i

# %%
print(place_hold)
# Out:
#  India will win the cricket world cup

# %%
nopunc=place_hold

# %%
print(nopunc)
# Out:
#  India will win the cricket world cup

# %%
nopunc.split()
# Out:
# ['India', 'will', 'win', 'the', 'cricket', 'world', 'cup']

# %%
clean_mess=[word for word in nopunc.split() if word.lower() not in stopwords.words('english')]

# %%
clean_mess
# Out:
# ['India', 'win', 'cricket', 'world', 'cup']

# %%
def text_processor(message):
    nopunc=[c for c in message if c not in string.punctuation]
    nopunc=''.join(nopunc)
    clean_mess=[word for word in nopunc.split() if word.lower() not in stopwords.words('english')]
    return clean_mess

# %%
df.head()
# Out:
#   Label                                            Message  length
# 0   ham  Go until jurong point, crazy.. Available only ...     111
# 1   ham                      Ok lar... Joking wif u oni...      29
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...     155
# 3   ham  U dun say so early hor... U c already then say...      49
# 4   ham  Nah I don't think he goes to usf, he lives aro...      61

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
bow_transformer=CountVectorizer(analyzer=text_processor).fit(df['Message'])

# %%
print(len(bow_transformer.vocabulary_))
# Out:
# 11425

# %%
mess4=df['Message'][3]

# %%
print(mess4)
# Out:
# U dun say so early hor... U c already then say...

# %%
messages_bow=bow_transformer.transform(df['Message'])

# %%
print("Shape of Sparse Matrix",messages_bow.shape)
# Out:
# Shape of Sparse Matrix (5572, 11425)

# %%
print(messages_bow)
# Out:
#   (0, 1110)	1
#   (0, 1483)	1
#   (0, 2060)	1
#   (0, 4653)	1
#   (0, 5217)	1
#   (0, 5218)	1
#   (0, 5769)	1
#   (0, 6217)	1
#   (0, 6906)	1
#   (0, 6937)	1
#   (0, 7555)	1
#   (0, 7668)	1
#   (0, 8336)	1
#   (0, 8917)	1
#   (0, 10965)	1
#   (0, 11163)	1
#   (1, 2451)	1
#   (1, 3064)	1
#   (1, 7701)	1
#   (1, 8590)	1
#   (1, 10698)	1
#   (1, 11072)	1
#   (2, 73)	1
#   (2, 423)	1
#   (2, 430)	1
#   :	:
#   (5568, 6691)	1
#   (5568, 6882)	1
#   (5568, 7159)	1
#   (5568, 11418)	1
#   (5569, 3228)	1
#   (5569, 3721)	1
#   (5569, 8252)	1
#   (5569, 10199)	1
#   (5570, 4508)	1
#   (5570, 5055)	1
#   (5570, 5251)	1
#   (5570, 6282)	1
#   (5570, 6699)	1
#   (5570, 6799)	1
#   (5570, 6984)	1
#   (5570, 7287)	1
#   (5570, 7394)	1
#   (5570, 7800)	1
#   (5570, 8420)	1
#   (5570, 9915)	1
#   (5570, 10787)	1
#   (5570, 11006)	1
#   (5571, 3431)	1
#   (5571, 8348)	1
#   (5571, 10648)	1

# %%
sparsity=(100.0*messages_bow.nnz/(messages_bow.shape[0]*messages_bow.shape[1]))

# %%
print("Sparsity:{}".format(sparsity))
# Out:
# Sparsity:0.07940295412668218

# %%
from sklearn.feature_extraction.text import TfidfTransformer

# %%
tfidf_transformer=TfidfTransformer().fit(messages_bow)

# %%
messages_tfidf=tfidf_transformer.transform(messages_bow)

# %%
print(messages_tfidf)
# Out:
#   (0, 11163)	0.23026685592418913
#   (0, 10965)	0.19073428545061483
#   (0, 8917)	0.24704652376837993
#   (0, 8336)	0.17046869292195632
#   (0, 7668)	0.26403384065473806
#   (0, 7555)	0.31253856260694546
#   (0, 6937)	0.1834692413608692
#   (0, 6906)	0.15158474664662352
#   (0, 6217)	0.18915557732842803
#   (0, 5769)	0.24984711892976424
#   (0, 5218)	0.26870593862526665
#   (0, 5217)	0.29835184088197164
#   (0, 4653)	0.31253856260694546
#   (0, 2060)	0.24203960256420656
#   (0, 1483)	0.31253856260694546
#   (0, 1110)	0.2882862016308418
#   (1, 11072)	0.40061560982443056
#   (1, 10698)	0.2063637481323008
#   (1, 8590)	0.5043405901305854
#   (1, 7701)	0.3767401070812794
#   (1, 3064)	0.2911995411244838
#   (1, 2451)	0.561988811929381
#   (2, 11123)	0.19104387220509106
#   (2, 11084)	0.15898145347176754
#   (2, 10686)	0.13995540820792943
#   :	:
#   (5568, 6882)	0.31367469776242124
#   (5568, 6691)	0.47781076401785183
#   (5568, 6354)	0.5575721048646767
# ...

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
spam_detect_model=MultinomialNB().fit(messages_tfidf,df['Label'])

# %%
from sklearn.model_selection import train_test_split

# %%
msg_train,msg_test,label_train,label_test=train_test_split(df['Message'],df['Label'])

# %%
from sklearn.pipeline import Pipeline
